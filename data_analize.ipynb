# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
def del_col(df: pd.DataFrame, columns: list):

    if type(columns) is list:
        df = df.drop([columns], axis=1)

    return df

# %%
def mape(y_true, y_pred):
    '''
    Метрика
    '''
    return np.mean(np.abs((y_pred-y_true)/y_true))

# %%
def display_data(dataframe, list_columns=None):
    '''
    Развернутая информация по датасету с фильтрацией по списку колонок,
    по умолчнию без фильтрации,
    названия признаков упорядочены по алфавиту
    '''
    if list_columns==None:
        index_ = sorted(dataframe.columns)
    else: 
        index_ = sorted([x for x in set(dataframe.dtypes.index).intersection(set(list_columns))])
    
    df = dataframe[index_]
    d = pd.concat([df.dtypes,df.count() + df.isna().sum(),\
               round((df.isna().sum()/(df.count() + df.isna().sum()))*100,2),df.nunique(),],axis=1)
    d.columns = ['Тип', 'Общ.кол', '% пропусков','Кол-во уник.значений']
    display(d)
    
    return

# %%
def show_correlation(df, features):
    '''
    plot correlation matrix
    '''
    
    #corr_matrix = df.drop(categorial_feature, axis=1).corr()
    corr_matrix = df[features].corr()
    plt.rcParams['figure.figsize'] = (15,15)
    sns.heatmap(corr_matrix, square=True,
                annot=True, fmt=".1f", linewidths=0.1, cmap="RdBu")
    plt.tight_layout()
    
    return

# %%
df = pd.read_csv('./dataset_all.csv', index_col=0)
display_data(df)
# Out:
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type         object    71989         0.00                    11
# desc              object    71989         0.00                 58395
# engine_capacity  float64    71989         0.12                    57
# engine_power     float64    71989         0.08                   344
# fuel_type         object    71989         0.00                     5
# mileage          float64    71989        16.53                 14638
# model             object    71989         0.00                    29
# model_2           object    71989         0.00                   962
# name              object    71989         0.00                 53807
# params            object    71989         0.00                 49677
# price              int64    71989         0.00                  5119
# region            object    71989         0.00                   447
# transmission      object    71989         0.00                     4
# wheel             object    71989         0.00                     3
# year               int64    71989         0.00                    73

# %%
#исправление пропусков
df['mileage'].fillna(0, inplace=True)
display_data(df)
# Out:
# C:\Users\sante\AppData\Local\Temp\ipykernel_6868\494701168.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mileage'].fillna(0, inplace=True)
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type         object    71989         0.00                    11
# desc              object    71989         0.00                 58395
# engine_capacity  float64    71989         0.12                    57
# engine_power     float64    71989         0.08                   344
# fuel_type         object    71989         0.00                     5
# mileage          float64    71989         0.00                 14639
# model             object    71989         0.00                    29
# model_2           object    71989         0.00                   962
# name              object    71989         0.00                 53807
# params            object    71989         0.00                 49677
# price              int64    71989         0.00                  5119
# region            object    71989         0.00                   447
# transmission      object    71989         0.00                     4
# wheel             object    71989         0.00                     3
# year               int64    71989         0.00                    73

# %%
df.loc[(df['engine_capacity'].isnull()) & (df['fuel_type'] == 'электро'), 'engine_capacity'] = 0.0
display_data(df)
# Out:
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type         object    71989         0.00                    11
# desc              object    71989         0.00                 58395
# engine_capacity  float64    71989         0.00                    58
# engine_power     float64    71989         0.08                   344
# fuel_type         object    71989         0.00                     5
# mileage          float64    71989         0.00                 14639
# model             object    71989         0.00                    29
# model_2           object    71989         0.00                   962
# name              object    71989         0.00                 53807
# params            object    71989         0.00                 49677
# price              int64    71989         0.00                  5119
# region            object    71989         0.00                   447
# transmission      object    71989         0.00                     4
# wheel             object    71989         0.00                     3
# year               int64    71989         0.00                    73

# %%
df.loc[df['engine_power'].isnull(), 'engine_power'] = df.loc[df['engine_power'].isnull(), 'engine_capacity'].apply(lambda x: df.groupby('engine_capacity')['engine_power'].mean()[x])
#df.loc[df['engine_power'].isnull(), 'engine_capacity'].apply(lambda x: df.groupby('engine_capacity')['engine_power'].mean()[x])
display_data(df)
# Out:
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type         object    71989          0.0                    11
# desc              object    71989          0.0                 58395
# engine_capacity  float64    71989          0.0                    58
# engine_power     float64    71989          0.0                   354
# fuel_type         object    71989          0.0                     5
# mileage          float64    71989          0.0                 14639
# model             object    71989          0.0                    29
# model_2           object    71989          0.0                   962
# name              object    71989          0.0                 53807
# params            object    71989          0.0                 49677
# price              int64    71989          0.0                  5119
# region            object    71989          0.0                   447
# transmission      object    71989          0.0                     4
# wheel             object    71989          0.0                     3
# year               int64    71989          0.0                    73

# %%
#df.year.value_counts()

df = df.drop('params', axis=1)
df = df.drop('name', axis=1)
df
# Out:
#               price                                               desc  \
# 3883899162  2570000  Данный автомобиль прошел юридическую проверку,...
# 3719132447  2595000  Дополнительная скидка до 300 000 рублей при по...
# 3662013276  1299000  Оставить заявку на рассрочку Оставить заявку н...
# 3612342601  6999000  Автомобиль из Германии. Идеальное состояние, п...
# 3566107102  2279000  Оставить заявку на рассрочку Оставить заявку н...
# ...             ...                                                ...
# 4162350483   349000  Продам Ваз 2112 2008г. Я Собственник по докуме...
# 3709120114   935000  Машина в отличном состоянии. Без Дтп. Кузов в ...
# 3747662839   380000  Рaсчeт кpeдита пo Телефоhу за 5 мин. Комплекта...
# 3469898222   750000  Специальные Условия Для Каждого! Спешите Время...
# 3657376846   137000  Продаю в хорошем состояние ваз 2114. Птс ориги...
#
#                            region   mileage  engine_capacity transmission  \
# 3883899162                 Москва   24831.0              1.4          AMT
# 3719132447                 Москва  116401.0              2.0          AMT
# 3662013276                 Москва   98000.0              1.4          AMT
# 3612342601                 Москва   78000.0              3.0           AT
# 3566107102                 Москва  172000.0              2.0          AMT
# ...                           ...       ...              ...          ...
# 4162350483       Челябинская обл.  100000.0              1.6           MT
# 3709120114    Ставропольский край  186000.0              1.6           MT
# 3747662839  Удмуртская Республика   73887.0              1.6           MT
# 3469898222        Санкт-Петербург   87453.0              1.6           MT
# 3657376846        Пензенская обл.  148000.0              1.5           MT
#
#             engine_power    body_type     wheel fuel_type  model  \
# 3883899162         150.0        седан  передний    бензин  Audi
# 3719132447         249.0      лифтбек    полный    бензин  Audi
# 3662013276         122.0        седан  передний    бензин  Audi
# 3612342601         231.0  внедорожник    полный    дизель  Audi
# 3566107102         249.0        седан    полный    бензин  Audi
# ...                  ...          ...       ...       ...    ...
# 4162350483          90.0      хетчбэк  передний    бензин   ВАЗ
# 3709120114         106.0        седан  передний    бензин   ВАЗ
# 3747662839          98.0        седан  передний    бензин   ВАЗ
# 3469898222         106.0    универсал  передний    бензин   ВАЗ
# 3657376846          77.0      хетчбэк  передний    бензин   ВАЗ
#
#                        model_2  year
# 3883899162                  A4  2017
# 3719132447                  A7  2016
# 3662013276                  A3  2013
# 3612342601                  Q7  2021
# 3566107102                  A6  2017
# ...                        ...   ...
# 4162350483              (LADA)  2008
# 3709120114        (LADA) Vesta  2017
# 3747662839       (LADA) Priora  2011
# 3469898222       (LADA) Largus  2020
# 3657376846  (LADA) 2114 Samara  2006
#
# [71989 rows x 13 columns]

# %%
df['mileage'] = df['mileage'].astype(int)

df['engine_power'] = df['engine_power'].astype(int)
df
# Out:
#               price                                               desc  \
# 3883899162  2570000  Данный автомобиль прошел юридическую проверку,...
# 3719132447  2595000  Дополнительная скидка до 300 000 рублей при по...
# 3662013276  1299000  Оставить заявку на рассрочку Оставить заявку н...
# 3612342601  6999000  Автомобиль из Германии. Идеальное состояние, п...
# 3566107102  2279000  Оставить заявку на рассрочку Оставить заявку н...
# ...             ...                                                ...
# 4162350483   349000  Продам Ваз 2112 2008г. Я Собственник по докуме...
# 3709120114   935000  Машина в отличном состоянии. Без Дтп. Кузов в ...
# 3747662839   380000  Рaсчeт кpeдита пo Телефоhу за 5 мин. Комплекта...
# 3469898222   750000  Специальные Условия Для Каждого! Спешите Время...
# 3657376846   137000  Продаю в хорошем состояние ваз 2114. Птс ориги...
#
#                            region  mileage  engine_capacity transmission  \
# 3883899162                 Москва    24831              1.4          AMT
# 3719132447                 Москва   116401              2.0          AMT
# 3662013276                 Москва    98000              1.4          AMT
# 3612342601                 Москва    78000              3.0           AT
# 3566107102                 Москва   172000              2.0          AMT
# ...                           ...      ...              ...          ...
# 4162350483       Челябинская обл.   100000              1.6           MT
# 3709120114    Ставропольский край   186000              1.6           MT
# 3747662839  Удмуртская Республика    73887              1.6           MT
# 3469898222        Санкт-Петербург    87453              1.6           MT
# 3657376846        Пензенская обл.   148000              1.5           MT
#
#             engine_power    body_type     wheel fuel_type  model  \
# 3883899162           150        седан  передний    бензин  Audi
# 3719132447           249      лифтбек    полный    бензин  Audi
# 3662013276           122        седан  передний    бензин  Audi
# 3612342601           231  внедорожник    полный    дизель  Audi
# 3566107102           249        седан    полный    бензин  Audi
# ...                  ...          ...       ...       ...    ...
# 4162350483            90      хетчбэк  передний    бензин   ВАЗ
# 3709120114           106        седан  передний    бензин   ВАЗ
# 3747662839            98        седан  передний    бензин   ВАЗ
# 3469898222           106    универсал  передний    бензин   ВАЗ
# 3657376846            77      хетчбэк  передний    бензин   ВАЗ
#
#                        model_2  year
# 3883899162                  A4  2017
# 3719132447                  A7  2016
# 3662013276                  A3  2013
# 3612342601                  Q7  2021
# 3566107102                  A6  2017
# ...                        ...   ...
# 4162350483              (LADA)  2008
# 3709120114        (LADA) Vesta  2017
# 3747662839       (LADA) Priora  2011
# 3469898222       (LADA) Largus  2020
# 3657376846  (LADA) 2114 Samara  2006
#
# [71989 rows x 13 columns]

# %% [markdown]
# TODO:
#
# Исключить пропуски в данных
#
# Убрать ненужные колонки
#
# Привести некоторые категориальные признаки в номинальные
#
# Год - сделать красиво и удалить, где мало элементов
#
# Регион - убрать где мало элементов, мейби предобработать
#
# Трансмиссия, привод, тип топлива, тип кузова - данные хорошие
#
# Объем двигателя - есть выбросы
#
# Мощность двигателя - вроде все нормально

# %%
df[df['body_type'].isnull() == True].params.value_counts()
# Out:
# params
# 3.5 AT внедорожник, полный, бензин                6
# 12 км, 3.5 AT внедорожник, полный, бензин         4
# 2.7 MT фургон, задний, бензин                     3
# 1 км, 3.5 AT внедорожник, полный, бензин          3
# 15 км, 3.5 AT внедорожник, полный, бензин         3
# 3 км, 3.5 AT внедорожник, полный, бензин          3
# 2.9 MT фургон, полный, бензин                     2
# 16 км, 3.5 AT внедорожник, полный, бензин         2
# 35 км, 3.5 AT внедорожник, полный, бензин         1
# 40 км, 3.5 AT внедорожник, полный, бензин         1
# 23 км, 3.5 AT внедорожник, полный, бензин         1
# 900 км, 3.5 AT внедорожник, полный, бензин        1
# 58 км, 3.3 AT внедорожник, полный, дизель         1
# 5 км, 3.5 AT внедорожник, полный, бензин          1
# 1.5 AMT седан, передний, бензин                   1
# 104 898 км, 2 AT внедорожник, передний, бензин    1
# 110 273 км, 1.6 AT хетчбэк, передний, бензин      1
# 26 км, 3.5 AT внедорожник, полный, бензин         1
# 95 800 км, 1.5 AMT универсал, передний, дизель    1
# 2.8 MT минивэн, задний, дизель                    1
# 2.8 MT фургон, задний, дизель                     1
# 2.4 AT внедорожник, полный, бензин                1
# 7 000 км, 3.5 AT внедорожник, полный, бензин      1
# 35 930 км, 3.5 AT внедорожник, полный, бензин     1
# 14 км, 3.3 AT внедорожник, полный, дизель         1
# 8 000 км, 3.5 AT внедорожник, полный, бензин      1
# 38 101 км, 1.5 AT внедорожник, полный, бензин     1
# 55 км, 3.5 AT внедорожник, полный, бензин         1
# 20 км, 3.5 AT внедорожник, полный, бензин         1
# 175 км, 3.5 AT внедорожник, полный, бензин        1
# 214 000 км, 3.5 AT внедорожник, полный, бензин    1
# 18 км, 3.5 AT внедорожник, полный, бензин         1
# 53 км, 3.3 AT внедорожник, полный, дизель         1
# 75 км, 3.5 AT внедорожник, полный, бензин         1
# 3 100 км, 3.5 AT внедорожник, полный, бензин      1
# 22 км, 3.5 AT внедорожник, полный, бензин         1
# 213 105 км, 2.2 AT внедорожник, полный, дизель    1
# 100 000 км, 2 MT минивэн, передний, бензин        1
# 2.8 MT микроавтобус, задний, дизель               1
# Name: count, dtype: int64

# %%
display_data(df)
# Out:
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type         object    71989          0.0                    11
# desc              object    71989          0.0                 58395
# engine_capacity  float64    71989          0.0                    58
# engine_power       int32    71989          0.0                   344
# fuel_type         object    71989          0.0                     5
# mileage            int32    71989          0.0                 14639
# model             object    71989          0.0                    29
# model_2           object    71989          0.0                   962
# price              int64    71989          0.0                  5119
# region            object    71989          0.0                   447
# transmission      object    71989          0.0                     4
# wheel             object    71989          0.0                     3
# year               int64    71989          0.0                    73

# %%
for colum in ['body_type', 'fuel_type', 'model', 'model_2', 'region', 'transmission', 'wheel']:
    df[colum] = df[colum].astype('category').cat.codes

df = df.drop('desc', axis=1)
display_data(df)
# Out:
#                      Тип  Общ.кол  % пропусков  Кол-во уник.значений
# body_type           int8    71989          0.0                    11
# engine_capacity  float64    71989          0.0                    58
# engine_power       int32    71989          0.0                   344
# fuel_type           int8    71989          0.0                     5
# mileage            int32    71989          0.0                 14639
# model               int8    71989          0.0                    29
# model_2            int16    71989          0.0                   962
# price              int64    71989          0.0                  5119
# region             int16    71989          0.0                   447
# transmission        int8    71989          0.0                     4
# wheel               int8    71989          0.0                     3
# year               int64    71989          0.0                    73

# %%
df.to_csv('./prod_data_all.csv', index=False)
