# %%
import pandas as pd
import seaborn as sns
import re
import matplotlib

# %%
def prepare_data(path):

    df = pd.read_csv(path, index_col=0)
    df[['mileage', 'engine_capacity', 'transmission', 'engine_power', 'body_type', 'wheel', 'fuel_type', 'model', 'model_2', 'year']] = None

    for i, row in df.loc[:, ['name', 'params', 'region']].iterrows():

        try:
            #Предобработка params
            mileage = re.search(r'([\d ]+) км,', row['params'], re.IGNORECASE)
            if mileage == None:
                mileage = 0
            else:
                df.loc[i, 'mileage'] = mileage.group(1).replace(' ', '')

            engine_capacity = re.search(r'([\d\.]+) [A-Z]+', row['params'])

            if engine_capacity != None:
                df.loc[i, 'engine_capacity'] = engine_capacity.group(1)

            df.loc[i, 'transmission'] = re.search(r'MT|CVT|AMT|AT', row['params'])[0]
            engine_power = re.search(r'\((\d+) л\.с\.\),', row['params'])

            if engine_power != None:
                df.loc[i, 'engine_power'] = engine_power.group(1)


            df.loc[i, 'body_type'] = re.search(r'([\w-]+), (?:полный|задний|передний)', row['params'], re.IGNORECASE).group(1)
            df.loc[i, 'wheel'] = re.search(r'полный|задний|передний', row['params'], re.IGNORECASE)[0]
            df.loc[i, 'fuel_type'] = re.search(r'бензин|дизель|электро|гибрид|газ', row['params'], re.IGNORECASE)[0]


            #предобработка name
            df.loc[i, 'model'] = re.search(r'[\w-]+ ', row['name'], re.IGNORECASE)[0]
            model_2 = re.search(r'^[\w-]+ ([^,]*?)(?=,| \d\.\d )(?:AT|MT|AMT|CVT)?', row['name'], re.IGNORECASE) # original:[\w-]+ ([^,]*?) [\d\. ]*(?:AT|MT|AMT|CVT)?,

            #if model_2 != None:
            df.loc[i, 'model_2'] = model_2.group(1)
            #else:
            #    df.loc[i, 'model_2'] = re.search(r'[\w-]+ ([^,]*?),', row['name'], re.IGNORECASE).group(1)

            df.loc[i, 'year'] = re.search(r', ?(\d{4})', row['name']).group(1)

            #предобработка region
            df.loc[i, 'region'] = re.search(r'([^,]+),?', row['region'], re.IGNORECASE).group(1)

        except Exception as ex:
            print(row)
            print(ex)

    return df

# %%
test = prepare_data('./datasets/dataset.csv')
test['model_2'].value_counts()
# Out:
# C5               1671
# RX               1452
# Focus            1241
# Dashing          1184
# 500              1103
#                  ...
# Hilux Surf          1
# Grand Hiace         1
# Picnic              1
# Corolla Ceres       1
# 3159                1
# Name: model_2, Length: 920, dtype: int64

# %%
for i in test['model_2'].unique():
    print(i)
# Out:
# A4
# A7
# A3
# Q7
# A6
# A5
# TT
# SQ7
# Q5
# Q3
# SQ5 Sportback
# S6
# S5
# S8
# A8
# A6 Allroad Quattro
# 80
# Q8
# A1
# e-tron Sportback AT
# 100
# Q3 Sportback
# RS Q8
# TTS
# A4 Allroad Quattro
# 90
# S4
# SQ5
# V8
# RS6
# e-tron AT
# Q5 Sportback
# RS4
# 200
# S7
# RS3
# RS7
# SQ8
# A2
# S3
# RS Q3
# Q8 Sportback e-tron AT
# Q5 e-tron AT
# X6
# X5
# X4
# X3
# 5 серия
# X7
# 3 серия
# 4 серия Gran Coupe
# 7 серия
# 1 серия
# M4
# 4 серия
# 8 серия
# 6 серия
# X6 M
# 2 серия Gran Tourer
# X1
# 3 серия GT
# iX AT
# 5 серия GT
# M3
# X2
# 6 серия Gran Coupe
# M5
# M8
# 2 серия Gran Coupe
# 2 серия
# 8 серия Gran Coupe
# 340
# XM
# Z4
# M6
# X3 M
# 6 серия GT
# i3 AT
# E3
# X5 M
# CS55 Plus
# CS35 Plus
# UNI-T
# Eado Plus
# Star Five
# UNI-K
# CS35
# Alsvin
# Lamore
# CS95
# UNI-V
# CS85
# Benben E-Star AMT
# Hunter Plus
# CS75 Plus
# CS75
# Auchan X5
# Shenlan (Deepal) S7
# CS55
# Hunter
# Lumin AT
# Kaicene F70
# Auchan X7 EV AT
# Auchan Z6
# M80
# Xingka Plus (Shenqi Plus)
# Eado
# Eado EV AT
# Raeton Plus
# CS95 Plus
# Auchan X7
# Raeton
# Tiggo 7 Pro Max
# Tiggo 8
# Tiggo 7 Pro
# Arrizo 8
# eQ7 AT
# Tiggo 8 Pro Max
# Tiggo 4 Pro
# Explore 06
# Tiggo 4
# Bonus 3 (E3)
# Amulet (A15)
# Tiggo 8 Pro
# Fora (A21)
# Bonus (A13)
# Tiggo (T11)
# IndiS (S18D)
# M11 (A3)
# Tiggo 7 Plus
# Tiggo 5
# Very
# Tiggo 7
# QQ6 (S21)
# Tiggo 2
# Tiggo 3
# Eastar
# Tiggo 8 Pro (China)
# CrossEastar (B14)
# Sweet (QQ)
# Tiggo 2 Pro
# Kimo (A1)
# Tiggo 9
# Arrizo 7
# E5
# Tiggo 8 Plus
# Arrizo 5 GT
# Tiggo 5x
# Tiggo 7 Pro Plug-in Hybrid
# Tiggo 3x
# Tiggo 8 Pro e+
# eQ1 AT
# Aveo
# Cruze
# Trax
# Epica
# Captiva
# Niva
# Spark
# Lacetti
# Tahoe
# Traverse
# Orlando
# Lanos
# Malibu
# Cobalt
# Camaro
# Equinox
# Blazer
# Corvette
# Monza
# Rezzo
# TrailBlazer
# Evanda
# Viva
# Tracker
# Express
# Cruze HR
# Suburban
# Colorado
# Volt
# Van
# Impala
# Astro
# Groove
# Damas
# TXL
# RX
# LX
# VX
# TX
# Kuga
# S-MAX
# Mondeo
# EcoSport
# Tourneo Custom
# Focus
# Transit
# Explorer
# Galaxy
# C-MAX
# Tourneo Connect
# Escape
# Fiesta
# Fusion
# Mustang
# Bronco Sport
# Ranger
# Edge
# Fusion (North America)
# Sierra
# Maverick
# Transit Connect
# Puma
# Taurus
# Focus RS
# Flex
# Escort
# Transit Custom
# Grand C-MAX
# Scorpio
# Tourneo
# Freestyle
# F-150
# Bronco
# Okavango
# Boyue Cool
# Boyue L
# Tugella
# Emgrand X7
# Preface
# Coolray
# Atlas
# Emgrand
# Atlas Pro
# Emgrand 7
# Monjaro
# Emgrand EC7
# CK (Otaka)
# GC6
# MK
# FC (Vision)
# Galaxy L7
# MK Cross
# Xingyue L
# Vision X6 Pro
# Geometry E AT
# Farizon FX
# Binrui Cool
# Binyue Cool
# Emgrand GT
# GS
# Icon
# Jiaji
# Geometry A AT
# Galaxy E8 AT
# Geometry C AT
# F7
# H5
# Jolion
# Dargo
# F7x
# H6
# H2
# H9
# H6S
# Dargo X
# Xiaolong Max
# DaGou (Big Dog)
# KuGou (Cool Dog)
# H8
# Freed
# Pilot
# N-BOX Slash
# CR-V
# Fit Shuttle
# Stepwgn
# FR-V
# Shuttle
# Accord
# Fit
# Jazz
# Stream
# Torneo
# Civic
# N-BOX
# Freed+
# e:NS1 AT
# N-VAN
# HR-V
# Legend
# Mobilio
# S660
# Odyssey
# Insight
# Elysion
# Vezel
# Civic Ferio
# Crossroad
# Element
# e:NP1 AT
# Integra
# Inspire
# Domani
# Partner
# Avancier
# Rafaga
# Ridgeline
# Fit Aria
# Crosstour
# Airwave
# Saber
# Prelude
# Zest
# Jade
# Odyssey (North America)
# Logo
# Crider
# S2000
# Ascot
# City
# Orthia
# N-WGN
# Concerto
# Capa
# Mobilio Spike
# Life
# UR-V
# X-NV AT
# Everus VE-1 AT
# CR-X
# Acty
# Z
# S-MX
# Integra SJ
# Breeze
# M-NV AT
# Ascot Innova
# N-One
# CR-Z
# Vamos
# Edix
# Creta
# Elantra
# ix35
# Genesis
# Santa Fe
# Solaris
# Tucson
# Sonata
# i40
# H-1
# Getz
# Coupe
# Accent
# Palisade
# i30
# Kona
# Avante
# Verna
# Grand Starex
# Porter
# Tiburon
# Mufasa
# Starex
# Grand Santa Fe
# Equus
# i20
# ix55
# Grace
# Matrix
# Terracan
# Veloster
# Grandeur
# Staria
# Trajet
# i10
# Lantra
# X70 Plus
# X90 Plus
# Dashing
# X70
# Traveler
# T2
# X70S
# X90
# Soul
# Ceed
# Optima
# Rio
# Sportage
# Cerato
# Stinger
# Mohave
# Rio X-Line
# Sorento
# Magentis
# Seltos
# Opirus
# K5
# Spectra
# Carnival
# Quoris
# Ceed GT
# Picanto
# K3
# Sorento Prime
# Shuma
# Rio X
# K900
# Carens
# Sephia
# Stonic
# Bongo
# Besta
# Clarus
# Venga
# Pride
# ES
# LS
# RC
# GX
# NX
# CT
# IS
# LC
# UX
# GS F
# IS F
# RC F
# SC
# RZ AT
# HS
# LM
# 6
# CX-5
# CX-7
# CX-9
# 3
# Biante
# 2
# CX-3
# Demio
# CX-4
# 3 MPS
# 5
# Verisa
# Familia
# CX-60
# 626
# 323
# Premacy
# Capella
# MPV
# Protege
# Tribute
# Millenia
# RX-7
# RX-8
# Eunos 800
# CX-30
# B-Series
# Atenza
# MX-6
# Axela
# 6 MPS
# MX-5
# Roadster
# CX-50
# Xedos 6
# BT-50
# 121
# Efini MS-8
# Eunos Presso
# Bongo Friendee
# MX-30 AT
# A-класс
# CLA-класс
# GLA-класс
# AMG GT
# Vito
# B-класс
# GLE-класс
# C-класс
# GLC-класс
# GL-класс
# V-класс
# S-класс AMG
# GLE-класс AMG
# GLS-класс
# Sprinter Classic
# GLK-класс
# S-класс
# SL-класс AMG
# GLS-класс AMG
# M-класс
# E-класс
# CLK-класс
# M-класс AMG
# Sprinter
# W124
# CLS-класс
# EQC AT
# CLS-класс AMG
# GLE-класс AMG Coupe
# GLE-класс Coupe
# Maybach S-класс
# GLC-класс Coupe
# T1
# G-класс AMG
# G-класс
# Viano
# GLB-класс
# E-класс AMG
# CL-класс
# Vario
# CLA-класс AMG
# 190 (W201)
# GLC-класс AMG
# CL-класс AMG
# R-класс
# CLC-класс
# A-класс AMG
# C-класс AMG
# SLK-класс
# SLR McLaren
# GLA-класс AMG
# GLC-класс AMG Coupe
# Maybach GLS-класс
# E-класс All-Terrain
# W123
# Citan
# GL-класс AMG
# EQV AT
# Montero Sport
# Pajero
# Galant
# Outlander
# Carisma
# L200
# Pajero iO
# Pajero Sport
# ASX
# Lancer
# Pajero Pinin
# EK Space
# Montero
# Grandis
# Legnum
# RVR
# Xpander
# Colt
# EK Wagon
# Space Star
# Mirage
# Lancer Cedia
# L300
# Eclipse Cross
# Dion
# Pajero Junior
# Outlander Sport
# Delica
# Dingo
# Minica
# Airtrek
# Toppo
# Eclipse
# Xpander Cross
# L400
# EK Wagon X
# Libero
# Minicab
# Sigma
# Diamante
# Pajero Mini
# Space Gear
# Chariot
# GTO
# Space Wagon
# EK Sport
# Delica D5
# Lancer Evolution
# Delica D3
# Jeep
# i
# i-MiEV AT
# FTO
# Airtrek AT
# S5 GT
# C5
# Insignia
# Astra OPC
# Mokka
# Antara
# Grandland X
# Zafira
# Meriva
# Astra GTC
# Combo
# Insignia OPC
# Vectra
# Corsa
# Astra
# Omega
# Agila
# Tigra
# Frontera
# Sintra
# Vivaro
# Movano
# Vita
# Ascona
# Zafira Life
# Rekord
# Manta
# Crossland X
# Kadett
# Combo Life
# Signum
# 408
# 5008
# Boxer
# 3008
# 2008
# 307
# 308
# RCZ
# 107
# 406
# 207
# Expert
# Traveller
# 206
# 208
# 4007
# 4008
# 306
# 508
# 405
# 301
# 407
# 607
# 106
# Bipper
# Rifter
# 207i
# 1007
# 404
# 807
# 605
# 504
# 205
# 806
# 108
# 309
# Logan Stepway
# Kaptur
# Dokker Stepway
# Arkana
# Sandero Stepway
# Koleos
# Logan
# Fluence
# Duster
# Grand Scenic
# Megane
# Sandero
# Symbol
# Clio
# Espace
# Laguna
# Clio RS
# 19
# Master
# Kangoo
# Kadjar
# Scenic
# Trafic
# Dokker
# Latitude
# Rapid
# Vel Satis
# Modus
# Talisman
# Twingo
# ZOE AT
# Safrane
# Grand Espace
# Octavia
# Yeti
# Superb
# Fabia
# Kodiaq
# Karoq
# Octavia Scout
# Roomster
# Praktik
# Felicia
# Octavia RS
# Kodiaq RS
# Kodiaq GT
# 300
# 500
# 400
# Verso
# C-HR
# Highlander
# Roomy
# RAV4
# Land Cruiser
# Corolla
# Land Cruiser Prado
# Sequoia
# Camry
# Carina
# Premio
# Supra
# bZ4X AT
# Vitz
# Auris
# Avensis
# Prius
# Caldina
# Isis
# Hilux
# Corolla Fielder
# Vista
# Aygo
# Sprinter Carib
# Starlet
# Mark II
# Chaser
# Sienna
# Allex
# Carina E
# Ist
# Harrier
# Estima
# Raum
# Alphard
# Regius
# Cavalier
# Platz
# Cresta
# Passo Sette
# Belta
# 4Runner
# Yaris
# Allion
# Celica
# WiLL
# Noah
# Verossa
# Sprinter Marino
# bB
# GT86
# Previa
# Cynos
# Corolla Spacio
# Venza
# Windom
# Succeed
# Tercel
# Rush
# Town Ace
# Mark X
# Duet
# Passo
# Probox
# Corona EXiV
# Fortuner
# Ipsum
# Altezza
# Corona
# Funcargo
# Tundra
# Corona Premio
# Sienta
# Brevis
# Crown
# Town Ace Noah
# Voxy
# Mark II Wagon Qualis
# Echo
# Carina ED
# Nadia
# Corolla Axio
# Crown Majesta
# Vellfire
# Lite Ace
# Hilux Surf
# Grand Hiace
# Picnic
# Corolla Ceres
# Tank
# Wish
# SAI
# Vios
# Aristo
# Sprinter Trueno
# Opa
# Camry Gracia
# Corolla II
# Polo
# ID.4 AT
# Passat
# ID.4 Crozz AT
# Multivan
# ID.6 Crozz AT
# Tiguan
# Amarok
# Passat CC
# Golf Plus
# Jetta
# Golf
# Caravelle
# Touareg
# ID.4 X AT
# Caddy
# Transporter
# Crafter
# Arteon
# Golf GTI
# Golf R
# Scirocco
# LT
# Touran
# Teramont
# Pointer
# Vento
# ID.6 X AT
# Bora
# Sharan
# Talagon
# Phaeton
# Beetle
# Lupo
# ID.3 AT
# CrossPolo
# Fox
# (LADA) XRAY
# (LADA) Largus
# (LADA) Vesta
# (LADA) Niva Legend
# (LADA) Granta
# (LADA) Vesta Cross
# (LADA) Kalina
# (LADA) 2114 Samara
# (LADA) 2113 Samara
# (LADA) 2111
# (LADA) 2115 Samara
# (LADA) 2112
# (LADA) Priora
# (LADA) 2105
# (LADA) 2106
# (LADA) 2110
# (LADA) 2107
# (LADA) 2104
# (LADA) 21099
# (LADA) 4x4 (Нива)
# (LADA) 2103
# (LADA) Largus Cross
# (LADA) 2109
# (LADA) Niva Travel
# (LADA) 2108
# (LADA) 2101
# (LADA) 1111 Ока
# (LADA) Kalina Cross
# (LADA) 2102
# (LADA) 2121 (4x4) Urban
# Соболь 2752
# ГАЗель Next
# ГАЗель 33023
# Соболь 2310
# 21 Волга
# ГАЗель 3302
# ГАЗель 2705
# Соболь 2217
# ГАЗель 2747
# 3102 Волга
# 31105 Волга
# 69
# ГАЗель 3221
# 3110 Волга
# 24 Волга
# 12 ЗИМ
# Volga Siber
# 31029 Волга
# M1
# М-20 Победа
# ГАЗель NN
# 3111 Волга
# Соболь NN
# 2330 Тигр
# 3105 Волга
# 310221 Волга
# 2308 Атаман
# Patriot
# 3909
# Карго
# Профи
# Pickup
# 39094
# 2206
# 3741
# 3962
# 31512
# 3303
# 31519
# 469
# 31514
# 3151
# Симбир
# 29891
# 2360
# 3153
# 452 Буханка
# 3160
# 39095
# 3159

# %%
print(a)
# Out:
# C5               1671
# RX               1452
# Focus            1241
# Dashing          1184
# 500              1103
#                  ...
# Hilux Surf          1
# Grand Hiace         1
# Picnic              1
# Corolla Ceres       1
# 3159                1
# Name: model_2, Length: 920, dtype: int64

# %%
path = './datasets/dataset.csv'
df = pd.read_csv(path, index_col=0)
for row in df.iloc[:10].loc[:, ['name', 'params', 'region']].iterrows():
    print(row)
# Out:
# (3883899162, name                       Audi A4 1.4 AMT, 2017, 24 831 км
# params    24 831 км, 1.4 AMT (150 л.с.), седан, передний...
# region                                               Москва
# Name: 3883899162, dtype: object)
# (3719132447, name                      Audi A7 2.0 AMT, 2016, 116 401 км
# params    116 401 км, 2.0 AMT (249 л.с.), лифтбек, полны...
# region                                               Москва
# Name: 3719132447, dtype: object)
# (3662013276, name                       Audi A3 1.4 AMT, 2013, 98 000 км
# params    98 000 км, 1.4 AMT (122 л.с.), седан, передний...
# region                                               Москва
# Name: 3662013276, dtype: object)
# (3612342601, name                        Audi Q7 3.0 AT, 2021, 78 000 км
# params    78 000 км, 3.0 AT (231 л.с.), внедорожник, пол...
# region                                               Москва
# Name: 3612342601, dtype: object)
# (3566107102, name                      Audi A6 2.0 AMT, 2017, 172 000 км
# params    172 000 км, 2 AMT (249 л.с.), седан, полный, б...
# region                                               Москва
# Name: 3566107102, dtype: object)
# (3671113158, name                      Audi A5 2.0 AMT, 2017, 190 000 км
# params    190 000 км, 2.0 AMT (249 л.с.), лифтбек, полны...
# region                                               Москва
# Name: 3671113158, dtype: object)
# (3317215204, name                      Audi A5 2.0 AMT, 2017, 141 500 км
# params    141 500 км, 2 AMT (249 л.с.), лифтбек, полный,...
# region                                      Московская обл.
# Name: 3317215204, dtype: object)
# (3678566832, name                        Audi Q7 3.0 AT, 2020, 94 900 км
# params    94 900 км, 3.0 AT (286 л.с.), внедорожник, пол...
# region                                      Санкт-Петербург
# Name: 3678566832, dtype: object)
# (3643807999, name                       Audi TT 2.0 AMT, 2020, 12 000 км
# params    12 000 км, 2.0 AMT (245 л.с.), купе, полный, б...
# region                                      Санкт-Петербург
# Name: 3643807999, dtype: object)
# (3709123455, name                       Audi SQ7 4.0 AT, 2020, 67 437 км
# params    67 437 км, 4.0 AT (422 л.с.), внедорожник, пол...
# region                                               Москва
# Name: 3709123455, dtype: object)
